# %% [markdown]
# # python world module4 Assign

# %%
 # String Concatenation

# %%
string1 = 'Hello'
string2 = input("Enter your Name: ")

User = string1 + ' ' + string2

print(User)
# Out:
# Enter your Name:  Jeenah Pearly
# Hello Jeenah Pearly

# %%
# String 3

# %%
string3 = "Welcome to Python programming"

# Concatenate string 3 with the existing string
User = User + " " + string3

print(User)
# Out:
# Hello Jeenah Pearly Welcome to Python programming

# %%
# String Slicing and Indexing

# %%
name = input("Enter your Name: ")

string1 = "Hello"
string3 = "Welcome to Python programming"

Existing_User = string1 + " " + name + " " + string3
print("\nExisting_User:", Existing_User)
# Out:
# Enter your Name:  Jeenah Pearly
# Existing_User: Hello Jeenah Pearly Welcome to Python programming

# %%
# a. Print the first character

# %%
print("a. First character:", Existing_user[0])
# Out:
# a. First character: H

# %%
# b. Print the last character

# %%
print("b. Last character:", Existing_User[-1])
# Out:
# b. Last character: g

# %%
# c. Print the first 5 characters

# %%
print("c. First 5 characters:", Existing_User[:5])
# Out:
# c. First 5 characters: Hello

# %%
# d. Print the last 11 characters

# %%
print("d. Last 11 characters:", Existing_User[-11:])
# Out:
# d. Last 11 characters: programming

# %%
# e. Print the string in reverse

# %%
print("e. Reverse string:", Existing_User[::-1])
# Out:
# e. Reverse string: gnimmargorp nohtyP ot emocleW ylraeP haneeJ olleH

# %%
# f. Print the word "Python"

# %%
print("f. Word 'Python':", Existing_User[31:37])
# Out:
# f. Word 'Python': Python

# %%
# String Methods

# %%
strM = "Python beginner tutorial"

# a. Convert the sentence to uppercase 
print("a. Uppercase:", strM.upper())

# b. Convert the sentence to lowercase 
print("b. Lowercase:", strM.lower())

# c. Use capitalize() to return the sentence to the original input form 
print("c. Capitalized:", strM.capitalize()) 

# d. Count the total number of occurrences of character 't' 
print("d. Number of 't' occurrences:", strM.count('t')) 

# e. Replace all occurrences of "Python" with "Data Analytics" 
print("e. Replaced string:", strM.replace("Python", "Data Analytics"))
# Out:
# a. Uppercase: PYTHON BEGINNER TUTORIAL
# b. Lowercase: python beginner tutorial
# c. Capitalized: Python beginner tutorial
# d. Number of 't' occurrences: 3
# e. Replaced string: Data Analytics beginner tutorial

# %%
# Tuples (Creation, Modification and Access)

# %%
# Create the first tuple 
t1 = (10, 20, 30) 

# Create the second tuple 
t2 = (40, 50, 60) 

# a. Concatenate the two tuples 
t_combine = t1 + t2 
print("a. Combined tuple:", t_combine) 

# b. Repeat the elements of t_combine 3 times 
t_repeat = t_combine * 3 
print("b. Tuple repeated 3 times:", t_repeat)

# c. Access the 3rd element from t_combine 
print("c. 3rd element:", t_combine[2]) 

# d. Access the first three elements from t_combine 
print("d. First three elements:", t_combine[:3]) 

# e. Access the last three elements from t_combine 
print("e. Last three elements:", t_combine[-3:])
# Out:
# a. Combined tuple: (10, 20, 30, 40, 50, 60)
# b. Tuple repeated 3 times: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# c. 3rd element: 30
# d. First three elements: (10, 20, 30)
# e. Last three elements: (40, 50, 60)
